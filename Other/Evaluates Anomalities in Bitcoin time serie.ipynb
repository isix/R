# %% [markdown]
# # Evaluates Anomalities in Bitcoin time serie
#
# Using 'Anomaly Detection', in R, Bitcoin price, in US Dollar (US$), was evaluated in three scenarios.
#
# 1. Period between January 2016 throughout 2018 (present);
# 2. Period between January 2017 throughout 2018 (present);
# 3. Period of 2018.

# %% [markdown]
# ## Install and load required libraries

# %%
if(!require("coindeskr")) install.packages("coindeskr")
if(!require("anomalize")) install.packages("anomalize")
if(!require("tidyverse")) install.packages("tidyverse")

library(anomalize) #tidy anomaly detectiom
library(tidyverse) #tidyverse packages like dplyr, ggplot, tidyr
library(coindeskr) #bitcoin price extraction from coindesk
# Out:
# Loading required package: coindeskr
# Loading required package: anomalize
# Loading required package: tidyverse
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 2.2.1     v purrr   0.2.4
# v tibble  1.4.2     v dplyr   0.7.4
# v tidyr   0.8.0     v stringr 1.3.0
# v readr   1.1.1     v forcats 0.3.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# ## Two years length analysis
#
# ### Data import (2016-present)

# %%
# Bitcoin present comparing to 2016 |- 2017
btc <- get_historic_price(start = "2016-01-01")

btc_ts <- btc %>% rownames_to_column() %>% as.tibble() %>% 
  mutate(date = as.Date(rowname)) %>% select(-one_of('rowname'))

windows(width = 720, height = 320)

btc_ts %>% 
  time_decompose(Price, method = "stl", frequency = "auto", trend = "auto") %>%
  anomalize(remainder, method = "gesd", alpha = 0.05, max_anoms = 0.2) %>%
  plot_anomaly_decomposition() 

windows(width = 720, height = 320)
  
btc_ts %>% 
  time_decompose(Price) %>%
  anomalize(remainder) %>%
  time_recompose() %>%
  plot_anomalies(time_recomposed = TRUE, ncol = 3, alpha_dots = 0.5)  

btc_ts %>% 
  time_decompose(Price) %>%
  anomalize(remainder) %>%
  time_recompose() %>%
  filter(anomaly == 'Yes')
# Out:
# Converting from tbl_df to tbl_time.
# Auto-index message: index = date
# frequency = 7 days
# trend = 91 days
# Converting from tbl_df to tbl_time.
# Auto-index message: index = date
# frequency = 7 days
# trend = 91 days
# plot without title
# Converting from tbl_df to tbl_time.
# Auto-index message: index = date
# frequency = 7 days
# trend = 91 days
#     date       observed  season     trend    remainder  remainder_l1
# 1   2017-06-06 2914.082   1.2947126 2242.094   670.6933 -443.3735
# 2   2017-06-11 3018.545   0.1167148 2329.554   688.8740 -443.3735
# 3   2017-07-15 1993.259   1.7490051 2946.638  -955.1286 -443.3735
# 4   2017-07-16 1938.943   0.1167148 2978.081 -1039.2547 -443.3735
# 5   2017-07-17 2244.265  -1.4276982 3009.523  -763.8299 -443.3735
# 6   2017-07-18 2327.898   1.2947126 3040.965  -714.3619 -443.3735
# 7   2017-07-19 2294.405   1.4473049 3072.407  -779.4491 -443.3735
# 8   2017-07-26 2550.180   1.4473049 3287.827  -739.0941 -443.3735
# ...

# %% [markdown]
# ## Two years length analysis
#
# ### Data import (2017-present)

# %%
# Bitcoin present comparing to 2017
rm(btc, btc_ts)

btc <- get_historic_price(start = "2017-01-01")

btc_ts <- btc %>% rownames_to_column() %>% as.tibble() %>% 
  mutate(date = as.Date(rowname)) %>% select(-one_of('rowname'))

windows(width = 720, height = 320)

btc_ts %>% 
  time_decompose(Price, method = "stl", frequency = "auto", trend = "auto") %>%
  anomalize(remainder, method = "gesd", alpha = 0.05, max_anoms = 0.2) %>%
  plot_anomaly_decomposition() 

windows(width = 720, height = 320)
  
btc_ts %>% 
  time_decompose(Price) %>%
  anomalize(remainder) %>%
  time_recompose() %>%
  plot_anomalies(time_recomposed = TRUE, ncol = 3, alpha_dots = 0.5)  

btc_ts %>% 
  time_decompose(Price) %>%
  anomalize(remainder) %>%
  time_recompose() %>%
  filter(anomaly == 'Yes')
# Out:
# Converting from tbl_df to tbl_time.
# Auto-index message: index = date
# frequency = 7 days
# trend = 90.5 days
# Converting from tbl_df to tbl_time.
# Auto-index message: index = date
# frequency = 7 days
# trend = 90.5 days
# plot without title
# Converting from tbl_df to tbl_time.
# Auto-index message: index = date
# frequency = 7 days
# trend = 90.5 days
#     date       observed  season       trend     remainder remainder_l1
# 1   2017-11-12  5857.318  35.76414457  7596.387 -1774.834 -1575.318
# 2   2017-12-04 11616.855  12.10540401  9690.178  1914.572 -1575.318
# 3   2017-12-05 11696.058  -0.09863276  9790.739  1905.418 -1575.318
# 4   2017-12-06 13708.991  -6.96525906  9891.300  3824.657 -1575.318
# 5   2017-12-07 16858.020  -1.92941630  9991.861  6868.088 -1575.318
# 6   2017-12-08 16057.145 -30.07220345  9973.089  6114.129 -1575.318
# 7   2017-12-09 14913.404  -8.80404040  9954.316  4967.892 -1575.318
# 8   2017-12-10 15036.956  35.76414457  9935.544  5065.648 -1575.318
# ...

# %% [markdown]
# ## 2018 analysis
#
# ### Data import (2018-present)

# %%
# Bitcoin present (2018)
rm(btc, btc_ts)

btc <- get_historic_price(start = "2018-01-01")

btc_ts <- btc %>% rownames_to_column() %>% as.tibble() %>% 
  mutate(date = as.Date(rowname)) %>% select(-one_of('rowname'))

windows(width = 720, height = 320)

btc_ts %>% 
  time_decompose(Price, method = "stl", frequency = "auto", trend = "auto") %>%
  anomalize(remainder, method = "gesd", alpha = 0.05, max_anoms = 0.2) %>%
  plot_anomaly_decomposition() 

windows(width = 720, height = 320)
  
btc_ts %>% 
  time_decompose(Price) %>%
  anomalize(remainder) %>%
  time_recompose() %>%
  plot_anomalies(time_recomposed = TRUE, ncol = 3, alpha_dots = 0.5)  

btc_ts %>% 
  time_decompose(Price) %>%
  anomalize(remainder) %>%
  time_recompose() %>%
  filter(anomaly == 'Yes')
# Out:
# Converting from tbl_df to tbl_time.
# Auto-index message: index = date
# frequency = 7 days
# trend = 54 days
# Converting from tbl_df to tbl_time.
# Auto-index message: index = date
# frequency = 7 days
# trend = 54 days
# plot without title
# Converting from tbl_df to tbl_time.
# Auto-index message: index = date
# frequency = 7 days
# trend = 54 days
#      date observed season trend remainder remainder_l1 remainder_l2 anomaly
#      recomposed_l1 recomposed_l2
# plot without title

# %% [markdown]
# ## Conclusion
#
# The comparison of these 3 periods suggests a structural break, or structural change, for Bitcoin price series. A structural break is an unexpected shift in a time series that can lead to huge forecasting errors and unreliability of the model in general.
# Being able to detect when the structure of the time series changes can give us insights into the problem we are studying. Structural break tests help us to determine when and whether there is a significant change in our data.
# Ideally, we should proceed a further data exploration using
# * Test for structural breaks with known break dates
# * Test for a structural break with an unknown break date
# * Wald and likelihood-ratio tests
# * Robust to heteroskedasticity
# * Cumulative sum (CUSUM) test for multiple breaks.
